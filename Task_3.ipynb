# %% [markdown]
# # By - Saurav Chaudhary

# %% [markdown]
# # GRIPNOV20 : TASK-3

# %% [markdown]
# # GRIP-The Sparks Foundation

# %% [markdown]
# ## <p style="font-family: Calibri; font-size:1.4em;color:Darkblue;">Exploratory Data Analysis - Retail</p>

# %% [markdown]
# ### <p style="font-family: Calibri; font-size:1.4em;color:Darkblue;"><u>Objective</u></p>

# %% [markdown]
# - As a business manager, try to find out the weak areas where you can work to make more profit.
# - What all business problems you can derive by exploring the data?

# %% [markdown]
# # Importing the important libraries

# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',150)
pd.set_option('display.max_rows',None)

# %%
#import the warnings.
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading and  Understanding the Data

# %%
#reading data from local
df=pd.read_csv("SampleSuperstore SPark intern.csv")

# %%
#reading the dataset
df.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#reading the shape of the dataset
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# - We have 9000+ rows and 13 columns in the dataset we recieved

# %%
#checking the data from statistical point of view 
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Identification of datatypes and variables

# %%
#checking the details of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# - We notice we have 5 numerical columns and the rest 8 columns are categorical columns

# %%
#checking only the datatypes 
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ### Data cleaning

# %%
#checking the null values in the dataset
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# - The dataset looks clean there is no missing values.
# - We can proceed with the data visualization process.

# %% [markdown]
# ### Data varaiables

# %% [markdown]
# #### Checking the categories of the variables

# %%
#checking the categories of the categorical features 
df["Ship Mode"].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
#checking the categories of the categorical features 
df["Segment"].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
#checking the categories of the categorical features 
df["Country"].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
#checking the categories of the categorical features 
df["City"].value_counts()
# Out:
# New York City        915
# Los Angeles          747
# Philadelphia         537
# San Francisco        510
# Seattle              428
# Houston              377
# Chicago              314
# Columbus             222
# San Diego            170
# Springfield          163
# Dallas               157
# Jacksonville         125
# Detroit              115
# Newark                95
# Richmond              90
# Jackson               82
# Columbia              81
# Aurora                68
# Phoenix               63
# Long Beach            61
# Arlington             60
# San Antonio           59
# Miami                 57
# Louisville            57
# Rochester             53
# Charlotte             52
# Henderson             51
# Lakewood              49
# Lancaster             46
# Milwaukee             45
# Fairfield             45
# Lawrence              44
# Denver                44
# Baltimore             43
# Pasadena              42
# San Jose              42
# Cleveland             42
# ...

# %%
#checking the categories of the categorical features 
df["State"].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
#checking the categories of the categorical features 
df["Region"].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
#checking the categories of the categorical features 
df["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
#checking the categories of the categorical features 
df["Sub-Category"].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate analysis

# %%
#visualizing the variables 
sns.countplot(x="Ship Mode",data=df)
plt.show()

# %% [markdown]
# - *More of the shipping mode was from the Standard class*

# %%
#visualizing the varaibale
sns.countplot(x="Segment",data=df)
plt.show()

# %% [markdown]
# - Consumer segment has larger participation as compared to other segments

# %%
#visualizing the varaibale
plt.figure(figsize=(20,15))
sns.countplot(x="State",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Few states have high activity in business
# - States like California,Texas,New York, Ohioetc. are active in the business
# - States like West Virginia, District of Columbia etc are least involved

# %%
#visualizing the varaibale
sns.countplot(x="Region",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - West is the highest participating region in the business than is the east. The business activity is least in the south

# %%
#visualizing the varaibale
sns.countplot(x="Category",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The office supplies are the highest ordered or preferred category .

# %%
grp_city=df.groupby(["City"]).sum().sort_values(by="Profit",ascending=False)
grp_city=grp_city[grp_city["Profit"]>6000]
grp_city
# Out:
#                Postal Code       Sales  Quantity  Discount      Profit
# City
# New York City      9168909  256368.161      3417      51.4  62036.9837
# Los Angeles       67252887  175851.341      2879      55.5  30440.7579
# Seattle           41989758  119540.742      1590      27.8  29156.0967
# San Francisco     47998395  112669.092      1935      34.0  17507.3854
# Detroit            5545741   42446.944       441       0.8  13181.7908
# Lafayette          1914474   25036.200       104       0.0  10018.3876
# Jackson            3585856   24963.858       318       2.5   7581.6828
# Atlanta            1182402   17197.840       156       0.0   6993.6629
# Minneapolis        1274361   16870.540        80       0.0   6824.5846
# San Diego         15650880   47521.029       670      13.6   6377.1960
# Springfield        9016357   43054.342       649      23.2   6200.6974

# %% [markdown]
# - New york city has larger participation in the business and thus top the char followed by Los Angeles .

# %%
#visualizing the varaibale
plt.figure(figsize=(12,10))
df["Sub-Category"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %% [markdown]
# - Among the categories we saw in the previous plot where Office supplies was the highest  the sub category that is the binders are the highest Office Supplies   in demand when it comes to  business

# %%
#visualizing the varaibale
sns.countplot(x="Sub-Category",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Numerical Variable Visualization

# %%
#checking the visualization on sales 
plt.figure(figsize=(20,10))
ax=sns.distplot(df["Sales"])
ax.set_yscale('log')

# %% [markdown]
# - The sales are higher in the range of 0-5000 and also mostly when the is the sales around 10,000 as the price is higher the sale has decreased .

# %%
#checking the visualization on profit 
plt.figure(figsize=(20,10))
ax=sns.distplot(df["Profit"])
ax.set_yscale('log')

# %% [markdown]
# - The profit is higher when the product rate is cheaper as the product rate is higher lower the sale and lower the profit .
# - Thus we can see only few profit noticed around the higher prices .

# %% [markdown]
# ### Bivariate Analysis

# %%
#Checking on the state variable with the profit
plt.figure(figsize=(20,10))
df_group=df.groupby(["State"])["Profit"].sum()
df_group.sort_values(ascending=False,inplace=True)
df_group.plot.bar()
plt.show()

# %% [markdown]
# - The state " California " Shows the highest profit
# - The states like New York , Washington etc shown good profit
# - On the other hand few states like Texas , Ohio has the reverse impact on the profit though the paticipation was more in these states still the states has shown loss than profit

# %%
#Checking on the Shipmode variable with the profit
plt.figure(figsize=(20,10))
df_group_city=df.groupby(["Ship Mode"])["Profit"].sum()
df_group_city.sort_values(ascending=False,inplace=True)
df_group_city.plot.bar()
plt.show()

# %% [markdown]
# - The Standard Class is a shipping mode making more profit among all the other mode

# %%
#Checking on the city  variable with the profit
plt.figure(figsize=(20,10))
df_group_city=df.groupby(["City"])["Profit"].sum()
df_top=df_group_city[df_group_city>5000]
df_top.sort_values(ascending=False,inplace=True)
df_top.plot.bar()
plt.show()

# %% [markdown]
# - We can observe few profit making cities like New york city,Los Angeles,Seattle etc .
# - We can focus on few cities which might see rise in the profit like Providence,Richmond,COlumbia etc,

# %%
#Checking on the city  variable with the sales
plt.figure(figsize=(20,10))
df_group_city=df.groupby(["City"])["Sales"].sum()
df_topsales=df_group_city[df_group_city>20000]
df_topsales.sort_values(ascending=False,inplace=True)
df_topsales.plot.bar()
plt.show()

# %% [markdown]
# - From the above we can observe that the cities like New York City , Los Angeles ,Seattle had good sales rate and thus had good profit too.
# - Thus focusing on the cities were sale was less may increase the profit. Cities like  Dellas, Arlington .etc

# %%
#the relation between the two variable profit and sales 
plt.figure(figsize=(12,8))
sns.scatterplot(df['Sales'],df['Profit'])

# %% [markdown]
# - We observe that the increase in the sales dosn't have much impact on the profit
# - At certain point the increase in sales have good impact on making the profit but after that when the sale is higher not much helping to earn profit.

# %%
#visualizing region and the quantity ordered from that region
plt.figure(figsize=(20,10))
sns.countplot("Region",data=df,hue="Quantity")
plt.title("Region and the Quantity Ordered")
plt.show()

# %% [markdown]
# - The west region is the highest in ordering and being active in the business.
# - The east region is the second highest in ordering the good amount of products of business .
# - we can assume the higher the quantity order the higher the sales and there is a good profit in that region

# %%
#visualizing the discounts in the region
plt.figure(figsize=(20,10))
sns.countplot("Region",data=df,hue="Discount")
plt.title("Region wise Discount")
plt.show()

# %% [markdown]
# - The west region gives more discount as compared to the other regions ie the discount of 80%
# - The second highest is the east region in providing the discounts
# - The more the discount in the region the higher the sales and the better the profit to that region.

# %%
#visualizing region and the quantity ordered from that region
plt.figure(figsize=(20,10))
sns.countplot("Category",data=df,hue="Quantity")
plt.title("Category and the Quantity Ordered")
plt.show()

# %% [markdown]
# - The office supplies was the highest in demand category among all with high quantity ordered

# %%
#visualizing region and the quantity ordered from that region
plt.figure(figsize=(20,10))
sns.countplot("Sub-Category",data=df,hue="Quantity")
plt.title("Category and the Sales")
plt.show()

# %% [markdown]
# - In the office supplies thesub category highly in demand is the Binders.
# - The paper also is one of the highest in demand sub category
# - We can say that most of the good profit is made by the supplies provided to the office as these supplies are high in demand and thus business is making good profit from it

# %%
#visualizing the category variable with the sales and region 
plt.figure(figsize = (20, 10))
ax=sns.boxplot(x = 'Category', y = 'Sales', hue = 'Region', data = df)
ax.set_yscale('log')
plt.show()

# %% [markdown]
# - The furniture have a good business in the western region and so is the technology
# - The office supply in the east is not much as the furniture in the east and the technology
# - The technology makes good profit in the south region

# %%
plt.figure(figsize = (20, 10))
ax=sns.boxplot(x = 'Segment', y = 'Sales', hue = 'Region', data = df)
ax.set_yscale('log')
plt.show()

# %% [markdown]
# - The Corporate segment in the west makes good sales.
# - The home office in thr Central also has a good profit making business
# - The consumers in all the regions are making a good profit

# %%
#visualizing the segment and the profit in the region 
plt.figure(figsize = (20, 15))
ax=sns.boxplot(x = 'Segment', y = 'Profit', hue = 'Region', data = df)
ax.set_yscale('log')
plt.show()

# %% [markdown]
# - The corporate segment is making good profit in the west region at the same time it has loss in the central region
# - The consumer segment in the south region shows the good profit in the business
# - All the segments in the central region should be taken care as  losses are also observed

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# - we can notice that across all the postal codes there was a good sales
# - The profit and the sales are not directly or inversly proportion to each other we can see that the higher the sale the profit also is higher but there is also some lossm observed when there was a sale

# %%
#heatmap to check the correlation of the dataset
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# - The correlation between Profit and sales do exist .
# When there is a sale there is a profit observed in the business
# - When the sales starts the quantity of the prodcut also increases as the price decreases
# - The discount is not much affecting the profit hence this feature should be taken care . May be the good discount may benifit the business
# - The focus on the central region should be more as more loss are observed there .
# - The discount is inversely proportional to the sales which has to be taken care .
# - Some of the segment like consumer and home office shows loss which need to be improved by looking at the other feature like sales and discount in that area.
